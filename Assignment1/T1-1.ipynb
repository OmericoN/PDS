# %%
import pandas as pd

df = pd.read_csv('gunrate.csv')
df.head()
# Out:
#    Rank    Location  Gun suicide rate  Suicide rate  Gun homicide rate  \
# 0     1     Wyoming              23.7          32.8                1.7
# 1     2     Montana              21.6          31.7                2.7
# 2     3      Alaska              19.4          30.0                4.2
# 3     4  New Mexico              14.4          25.2               10.9
# 4     5    Oklahoma              13.8          22.0                6.4
#
#    Homicide rate  % gun at home
# 0            2.8           61.0
# 1            4.2           65.0
# 2            6.7           57.0
# 3           14.5           36.0
# 4            8.6           55.0

# %%
df.dtypes
# Out:
# Rank                   int64
# Location              object
# Gun suicide rate     float64
# Suicide rate         float64
# Gun homicide rate    float64
# Homicide rate        float64
# % gun at home        float64
# dtype: object

# %%
df.describe()
# Out:
#             Rank  Gun suicide rate  Suicide rate  Gun homicide rate  \
# count  51.000000         51.000000     51.000000          49.000000
# mean   26.000000          9.764706     17.088235           6.446939
# std    14.866069          4.621118      5.626923           4.860346
# min     1.000000          1.800000      6.900000           0.900000
# 25%    13.500000          7.650000     14.100000           2.900000
# 50%    26.000000         10.200000     16.100000           5.300000
# 75%    38.500000         12.100000     20.350000           8.100000
# max    51.000000         23.700000     32.800000          25.200000
#
#        Homicide rate  % gun at home
# count      51.000000      50.000000
# mean        7.847059      39.720000
# std         5.788103      14.582685
# min         1.100000       9.000000
# 25%         4.150000      35.250000
# 50%         6.700000      40.000000
# 75%         9.850000      52.000000
# max        33.300000      65.000000

# %%
df["Gun homicide rate"].median()
# Out:
# np.float64(5.3)

# %%
minRow = df.iloc[df["Gun homicide rate"].idxmin()]
minRow
# Out:
# Rank                    19
# Location             Maine
# Gun suicide rate      11.5
# Suicide rate          20.2
# Gun homicide rate      0.9
# Homicide rate          1.5
# % gun at home         48.0
# Name: 18, dtype: object

# %%
df_s = df.sort_values(by="Gun homicide rate")

# %%
df_s
# Out:
#     Rank              Location  Gun suicide rate  Suicide rate  \
# 18    19                 Maine              11.5          20.2
# 49    50         Massachusetts               1.9           8.6
# 5      6                 Idaho              13.8          20.4
# 46    47                Hawaii               2.9          14.0
# 0      1               Wyoming              23.7          32.8
# 27    28                  Iowa               9.2          17.2
# 22    23                  Utah              10.9          19.3
# 39    40              Nebraska               7.4          14.7
# 45    46          Rhode Island               3.3          10.7
# 6      7          North Dakota              13.2          20.1
# 1      2               Montana              21.6          31.7
# 21    22          South Dakota              10.9          22.7
# 40    41             Minnesota               6.9          14.2
# 48    49            New Jersey               2.1           7.4
# ...
