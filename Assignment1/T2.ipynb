# %%
import pandas as pd
df = pd.read_csv('Gapminder1900.csv')

# %%
df.head()
# Out:
#   country.code  year year.cat  country               region  age.1st.marriage  \
# 0          dnk  1920   [1920]  Denmark  europe_central_asia               NaN
# 1          dnk  1921   [1921]  Denmark  europe_central_asia               NaN
# 2          dnk  1922   [1922]  Denmark  europe_central_asia               NaN
# 3          dnk  1923   [1923]  Denmark  europe_central_asia               NaN
# 4          dnk  1924   [1924]  Denmark  europe_central_asia               NaN
#
#    age_median  alcohol.consumption_for15plus  bmi_female  bmi_male  ...  \
# 0         NaN                            NaN         NaN       NaN  ...
# 1         NaN                            NaN         NaN       NaN  ...
# 2         NaN                            NaN         NaN       NaN  ...
# 3         NaN                            NaN         NaN       NaN  ...
# 4         NaN                            NaN         NaN       NaN  ...
#
#    population_urban.growth_percent  population_urban_percent  \
# ...

# %%
filtered = df[(df['country'] == 'Netherlands') & (df['year'] >= 2000) & (df['year'] <= 2015)]
filtered.head()
# Out:
#       country.code  year year.cat      country               region  \
# 10214          nld  2000   [2000]  Netherlands  europe_central_asia
# 10215          nld  2001   [2001]  Netherlands  europe_central_asia
# 10216          nld  2002   [2002]  Netherlands  europe_central_asia
# 10217          nld  2003   [2003]  Netherlands  europe_central_asia
# 10218          nld  2004   [2004]  Netherlands  europe_central_asia
#
#        age.1st.marriage  age_median  alcohol.consumption_for15plus  \
# 10214               NaN      37.526                            NaN
# 10215               NaN         NaN                            NaN
# 10216               NaN         NaN                            NaN
# 10217               NaN         NaN                            NaN
# 10218               NaN         NaN                            NaN
#
#        bmi_female  bmi_male  ...  population_urban.growth_percent  \
# 10214       25.00     25.26  ...                          1.71592
# ...

# %%
result = filtered[['year', 'country', 'infant.mortality_per1000', 'life.expectancy']]
result.head(16)
# Out:
#        year      country  infant.mortality_per1000  life.expectancy
# 10214  2000  Netherlands                       5.1            78.06
# 10215  2001  Netherlands                       5.0            78.22
# 10216  2002  Netherlands                       4.9            78.40
# 10217  2003  Netherlands                       4.7            78.67
# 10218  2004  Netherlands                       4.6            79.08
# 10219  2005  Netherlands                       4.5            79.42
# 10220  2006  Netherlands                       4.3            79.78
# 10221  2007  Netherlands                       4.2            80.11
# 10222  2008  Netherlands                       4.0            80.33
# 10223  2009  Netherlands                       3.8            80.54
# 10224  2010  Netherlands                       3.7            80.73
# 10225  2011  Netherlands                       3.6            80.92
# 10226  2012  Netherlands                       3.5            81.06
# ...

# %%
result.describe()
# Out:
#               year  infant.mortality_per1000  life.expectancy
# count    16.000000                 16.000000        16.000000
# mean   2007.500000                  4.106250        79.981875
# std       4.760952                  0.644431         1.207787
# min    2000.000000                  3.200000        78.060000
# 25%    2003.750000                  3.575000        78.977500
# 50%    2007.500000                  4.100000        80.220000
# 75%    2011.250000                  4.625000        80.955000
# max    2015.000000                  5.100000        81.620000
